# %% [markdown]
# Theory Questions

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
# - OOP is a programming model that organizes code into objects, which are instances of classes. Each object contains data (attributes) and functions (methods) that operate on that data.
#
# Example languages: Python, Java, C++
#
# Main principles: Encapsulation, Abstraction, Inheritance, Polymorphism.

# %% [markdown]
# 2. What is a class in OOP?
#
# - A class is a template or blueprint for creating objects. It defines what attributes and methods the created objects will have.

# %%
 #example
class Car:
    def _init_(self, brand):
        self.brand = brand

# %% [markdown]
# 3. What is an object in OOP?
#
# - An object is an instance of a class, representing a real-world entity. Each object has its own data stored in attributes.

# %%
# example
car1 = Car("Toyota")  # object of Car class

# %% [markdown]
# 4. Difference between Abstraction and Encapsulation
#
# - Abstraction: Focuses on what a class does, hiding the internal working details.
# Example: A Car.start() method hides the engine start process from the user.
#
# - Encapsulation: Restricts direct access to an object's data by using private variables and controlled access methods.
# Example: Private variables in Python using __var.

# %% [markdown]
# 5. What are dunder methods in Python?
#
# - "Dunder" = double underscore methods like _init, __str, __len_. They allow you to define special behaviors for your objects.

# %%
#example
def _str_(self):
    return f"Car brand: {self.brand}"

# %% [markdown]
# 6. Explain inheritance in OOP
#
# - Inheritance allows one class (child) to use attributes and methods from another class (parent).
#
# - Promotes code reuse.

# %%
#example
class ElectricCar(Car):
    def charge(self):
        print("Charging battery")

# %% [markdown]
# 7. What is polymorphism in OOP?
#
# - Polymorphism means one method name, many forms — different objects respond differently to the same method name.

# %%
#examle
class Dog:
    def speak(self):
        print("Woof!")

class Cat:
    def speak(self):
        print("Meow!")

# %% [markdown]
# 8. How is encapsulation achieved in Python?
#
# - By making variables private (_protected or __private) and providing getter/setter methods to access or update them safely.

# %% [markdown]
# 9. What is a constructor in Python?
#
# - A special method _init_ called automatically when an object is created, used to initialize attributes .

# %%
def _init_(self, brand):
    self.brand = brand

# %% [markdown]
#  10. What are class and static methods in Python?
#
# - Class method: Uses @classmethod and cls parameter. Works on the class itself, not an object.
#
# - Static method: Uses @staticmethod. Doesn’t need self or cls, works like a normal function inside a class.

# %% [markdown]
# 11. What is method overloading in Python?
#
# - True overloading (like in Java) isn’t supported. Achieved by using default parameters or *args to allow multiple behaviors.

# %% [markdown]
# 12. What is method overriding in OOP?
#
# - When a subclass provides a specific implementation of a method already defined in its parent class.

# %% [markdown]
# 13. What is a property decorator in Python?
#
# - @property lets you access a method as if it were an attribute, often used for read-only or computed properties.

# %% [markdown]
# 14. Why is polymorphism important in OOP?
#
# - It allows code flexibility, making it possible to use the same interface for objects of different classes, reducing code duplication.

# %% [markdown]
# 15. What is an abstract class in Python?
#
# A class that cannot be instantiated and contains abstract methods that must be implemented by subclasses. Created using the abc module.

# %% [markdown]
# 16. What are the advantages of OOP?
#
# - Object-oriented programming has several advantages:
#
# 1.Code reusability
#
# 2.Easier maintenance
#
# 3.Modularity
#
# 4.Scalability
#
# 5.Better problem modeling (real-world entities)

# %% [markdown]
# 17. Difference between class variable and instance variable
#
# - Class variable: Shared by all objects of the class.
#
# - Instance variable: Specific to a particular object.

# %% [markdown]
# 18. What is multiple inheritance in Python?
#
# - When a class inherits from more than one parent class.

# %%
#example
class C(A, B): pass

# %% [markdown]
# 19. Purpose of _str_ and _repr_ in Python
#
# - _str_ → Returns a readable, user-friendly string representation.
#
# - _repr_ → Returns an unambiguous, developer-focused string, ideally usable to recreate the object.

# %% [markdown]
# 19. What is multiple inheritance in Python?
# Multiple inheritance is when a class inherits from more than one parent class.

# %%
#example
class A: pass
class B: pass
class C(A, B): pass

#It allows a class to use attributes/methods from multiple sources.

# %% [markdown]
# 20. Explain the purpose of _str_ and _repr_ methods in Python.
#
# - _str_: Returns a user-friendly string representation of an object, used by print().
#
# - _repr_: Returns a developer-oriented string representation, ideally unambiguous, used in debugging and the REPL.

# %%
#example
def _str_(self): return "Nice view"
def _repr_(self): return "ObjectView(x=10, y=20)"

# %% [markdown]
# 21. What is the significance of the super() function in Python?
# super() is used to call methods from a parent (or sibling in MRO) class without explicitly naming it, helping in method overriding and multiple inheritance scenarios.

# %%
class Parent:
    def __init__(self):
        print("Parent class initialized")

class Child(Parent):
    def __init__(self):
        super().__init__()
        print("Child class initialized")

# Example of creating a Child object to see the output
child_obj = Child()
# Out:
# Parent class initialized
# Child class initialized

# %% [markdown]
# 22. What is the significance of the _del_ method in Python?
# _del_ is a destructor method, automatically called when an object is about to be destroyed (garbage collected). Used for cleanup tasks like closing files or releasing resources.

# %% [markdown]
# 23. What is the difference between @staticmethod and @classmethod in Python?
#
# @staticmethod: A method that does not access self or cls. It behaves like a normal function inside a class.
#
# @classmethod: Receives the class (cls) as the first argument, can modify class-level data.

# %% [markdown]
# 24. How does polymorphism work in Python with inheritance?
#
# - Polymorphism lets you use a single interface for different object types. In inheritance, a child class can override parent methods, and the same method name can perform different tasks depending on the object.

# %%
#example
for obj in [Dog(), Cat()]:
    obj.speak()  # Works differently for Dog and Cat
# Out:
# Woof!
# Meow!

# %% [markdown]
# 25. What is method chaining in Python OOP?
# Method chaining is calling multiple methods on the same object in a single line by returning self from each method.

# %%
#example
class Test:
    def step1(self): print("1"); return self
    def step2(self): print("2"); return self
obj = Test().step1().step2()
# Out:
# 1
# 2

# %% [markdown]
# Practical Questions

# %% [markdown]
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
# 1. Inheritance with method overriding
class Animal:
    def speak(self):
        print("Some generic animal sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

d = Dog()
d.speak()
# Out:
# Bark!

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
import math

# Abstract base class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

# Rectangle class
class Rectangle(Shape):
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth

    def area(self):
        return self.length * self.breadth

# Testing
shapes = [
    Circle(7),
    Rectangle(5, 8)
]

for s in shapes:
    print(f"{s.__class__.__name__} Area:", s.area())
# Out:
# Circle Area: 153.93804002589985
# Rectangle Area: 40

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute

# %%
#Multi-level inheritance
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

e = ElectricCar("Four Wheeler", "Tesla", "85 kWh")
print(e.type, e.brand, e.battery)
# Out:
# Four Wheeler Tesla 85 kWh

# %% [markdown]
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method

# %%
# 4. Polymorphism example
class Bird:
    def fly(self):
        print("Some birds can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high!")

class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly")

birds = [Sparrow(), Penguin()]
for b in birds:
    b.fly()
# Out:
# Sparrow flies high!
# Penguins can't fly

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
# Encapsulation example
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient funds")

    def check_balance(self):
        return self.__balance

acc = BankAccount(1000)
acc.deposit(500)
acc.withdraw(200)
print("Balance:", acc.check_balance())
# Out:
# Balance: 1300

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
 #Runtime polymorphism
class Instrument:
    def play(self):
        print("Playing an instrument")

class Guitar(Instrument):
    def play(self):
        print("Playing guitar")

class Piano(Instrument):
    def play(self):
        print("Playing piano")

for instrument in [Guitar(), Piano()]:
    instrument.play()
# Out:
# Playing guitar
# Playing piano

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
 #Class and static methods
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print("Add:", MathOperations.add_numbers(10, 5))
print("Subtract:", MathOperations.subtract_numbers(10, 5))
# Out:
# Add: 15
# Subtract: 5

# %% [markdown]
# 8. Implement a class Person with a class method to count the total number of persons created

# %%
#Counting number of persons
class Person:
    count = 0
    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person("Alice")
p2 = Person("Bob")
print("Total persons:", Person.total_persons())
# Out:
# Total persons: 2

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
# Fraction class with _str_ method override
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def _str_(self):
        return f"{self.numerator}/{self.denominator}"

f = Fraction(3, 4)
print(f)

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
# Operator overloading for Vector addition
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 5)
print(v1 + v2)
# Out:
# Vector(6, 8)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
#  Person class with greet method
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Parantap", 20)
p.greet()
# Out:
# Hello, my name is Parantap and I am 20 years old.

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
#Student class with average grade method
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades) if self.grades else 0

s = Student("Bob", [85, 90, 78])
print("Average Grade:", s.average_grade())
# Out:
# Average Grade: 84.33333333333333

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
# Rectangle class
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

        # Example usage
r = Rectangle()
r.set_dimensions(5, 3)
print("Area:", r.area())
# Out:
# Area: 15

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
# Employee and Manager classes
class Employee:
    def calculate_salary(self, hours_worked, hourly_rate):
        return hours_worked * hourly_rate

class Manager(Employee):
    def calculate_salary(self, hours_worked, hourly_rate, bonus):
        base_salary = super().calculate_salary(hours_worked, hourly_rate)
        return base_salary + bonus

        # Example usage
e = Employee()
print("Employee Salary:", e.calculate_salary(40, 15))

m = Manager()
print("Manager Salary:", m.calculate_salary(40, 15, 1000))
# Out:
# Employee Salary: 600
# Manager Salary: 1600

# %% [markdown]
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
# Product class
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

        # Example usage
p = Product("Laptop", 1000, 2)
print("Total Price:", p.total_price())
# Out:
# Total Price: 2000

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
#  Abstract Animal, Cow, and Sheep
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"
#example usage

cow = Cow()
sheep = Sheep()
print(cow.sound())
print(sheep.sound())
# Out:
# Moo
# Baa

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
#  Book class
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"{self.title} by {self.author}, published in {self.year_published}"

        # Example usage
book = Book("Python Programming", "John Doe", 2022)
print(book.get_book_info())
# Out:
# Python Programming by John Doe, published in 2022

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
# 18. House and Mansion classes
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
#example usage :

mansion = Mansion("123 Rich St", 1000000, 10)
print(f"Mansion Address: {mansion.address}, Price: {mansion.price}, Rooms: {mansion.number_of_rooms}")
# Out:
# Mansion Address: 123 Rich St, Price: 1000000, Rooms: 10
